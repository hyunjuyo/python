# %% [markdown]
# ## 네이버 금융
# - selenium
# - iframe
#     - HTML 안에 또 다른 HTML

# %%
import pandas as pd 
import time 
from selenium import webdriver

# %%
url = "https://finance.naver.com/marketindex/"
driver = webdriver.Chrome("../driver/chromedriver.exe") 
driver.get(url)

# %%
# 환전 고시 환율 
contents = driver.find_elements_by_css_selector("#exchangeList > li > a")
contents[0].find_element_by_css_selector(".value").text
# Out:
# '1,196.00'

# %%
# 주요뉴스 제목 
news = driver.find_elements_by_css_selector("#content > div.section_news > div > ul > li:nth-child(1) > p > a")
news[0].text
# Out:
# "[머니무브 시작됐나③]떠오르는 '원자재'."

# %%
# 밑 페이지에 있는, 매매기준율 
driver.find_elements_by_css_selector("body > div > table > tbody > tr")
# Out:
# []

# %% [markdown]
# ## iframe

# %%
# selenium을 이용한 방법

# %%
# iframe 태그 지정 

iframe = driver.find_element_by_css_selector("#frame_ex1")
# driver.find_element_by_id("frame_ex1")

# %%
# iframe 태그 이동 => switch_to_frame()
driver.switch_to_frame(iframe)
# Out:
# C:\Users\HJ\AppData\Local\Temp/ipykernel_25344/630311945.py:2: DeprecationWarning: use driver.switch_to.frame instead
#   driver.switch_to_frame(iframe)

# %%
# 태그가 현재 이동된 상태이기 때문에 위에서 정상 작동했던 "환전 고시 환율" 부분이
# 지금은 아래와 같이 정상 작동하지 않는 것을 확인 가능

# 환전 고시 환율 
contents = driver.find_elements_by_css_selector("#exchangeList > li > a")
contents[0].find_element_by_css_selector(".value").text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25344/1004729001.py in <module>
#       4 # 환전 고시 환율
#       5 contents = driver.find_elements_by_css_selector("#exchangeList > li > a")
# ----> 6 contents[0].find_element_by_css_selector(".value").text
#
# IndexError: list index out of range

# %%
driver.find_element_by_css_selector(".sale").text
# Out:
# '1,196.00'

# %%
# 이 상태에서 위에서 빈 list를 반환했던 코드를 다시 실행하면, 해당 값들을 반환함 확인 가능

# 밑 페이지에 있는, 매매기준율 
contents = driver.find_elements_by_css_selector("body > div > table > tbody > tr")
contents[:5]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="339193a9bcd874bafcd3bdd277fea33c", element="0ca073f5-6bde-408c-a35b-a84290a20d1a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="339193a9bcd874bafcd3bdd277fea33c", element="0cddd51c-e3f5-4823-95d7-5a7d14920847")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="339193a9bcd874bafcd3bdd277fea33c", element="5169a1c6-8ff2-4dfd-ba41-57891f006183")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="339193a9bcd874bafcd3bdd277fea33c", element="5b7dbfb3-388d-42b1-8977-5813cbb72ae8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="339193a9bcd874bafcd3bdd277fea33c", element="30d7b34c-cafd-4359-847c-ba47601064bb")>]

# %%
contents[0].find_element_by_css_selector(".sale").text
# Out:
# '1,196.00'

# %%
datas = [] 

for content in contents:
    title = content.find_element_by_css_selector(".tit > a").text
    sale = content.find_element_by_css_selector(".sale").text
    link = content.find_element_by_css_selector(".tit > a").get_attribute("href")
    datas.append({
        "title": title, 
        "sale": sale,
        "link": link
    })
    
df = pd.DataFrame(datas)
df.to_excel("./sel_naver_finance.xlsx", encoding="utf-8")
df
# Out:
#             title      sale                                               link
# 0          미국 USD  1,196.00  https://finance.naver.com/marketindex/exchange...
# 1        유럽연합 EUR  1,382.82  https://finance.naver.com/marketindex/exchange...
# 2   일본 JPY (100엔)  1,069.67  https://finance.naver.com/marketindex/exchange...
# 3          중국 CNY    185.31  https://finance.naver.com/marketindex/exchange...
# 4          홍콩 HKD    153.62  https://finance.naver.com/marketindex/exchange...
# 5          대만 TWD     42.59  https://finance.naver.com/marketindex/exchange...
# 6          영국 GBP  1,630.09  https://finance.naver.com/marketindex/exchange...
# 7          오만 OMR  3,106.49  https://finance.naver.com/marketindex/exchange...
# 8         캐나다 CAD    953.75  https://finance.naver.com/marketindex/exchange...
# 9         스위스 CHF  1,287.48  https://finance.naver.com/marketindex/exchange...
# 10        스웨덴 SEK    136.51  https://finance.naver.com/marketindex/exchange...
# ...

# %%
driver.quit()

# %%
# request를 이용한 방법

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/marketindex/exchangeList.naver"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<html lang=\'ko\'>\n<head>\n<title>\xb3\xd7\xc0\xcc\xb9\xf6 \xb1\xdd\xc0\xb6</title>\n<meta http-equiv=\'Content-Type\' content=\'text/html; charset=euc-kr\'>\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20210916165954/css/finance.css">\n\n<script language="javascript">document.domain="naver.com";</script>\n<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210916165954/js/info/jindo.min.ns.1.5.3.euckr.js"></script>\n<script type="text/javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20210916165954/js/lcslog.js"></script>\n</head>\n<body>\n<div class="tbl_area">\n\t<table border="1" class="tbl_exchange" summary="\xc8\xaf\xc0\xfc \xb0\xed\xbd\xc3 \xc8\xaf\xc0\xb2 \xb8\xae\xbd\xba\xc6\xae">\n\t<caption>\xc8\xaf\xc0\xfc \xb0\xed\xbd\xc3 \xc8\xaf\xc0\xb2</caption>\n\t<colgroup>\
# ...

# %%
soup = BeautifulSoup(response.content, "html.parser")
print(soup.prettify())
# Out:
# <html lang="ko">
#  <head>
#   <title>
#    네이버 금융
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="text/javascript" http-equiv="Content-Script-Type"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <link href="https://ssl.pstatic.net/imgstock/static.pc/20210916165954/css/finance.css" rel="stylesheet" type="text/css"/>
#   <script language="javascript">
#    document.domain="naver.com";
#   </script>
#   <script src="https://ssl.pstatic.net/imgstock/static.pc/20210916165954/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
#   </script>
#   <script src="https://ssl.pstatic.net/imgstock/static.pc/20210916165954/js/lcslog.js" type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <div class="tbl_area">
#    <table border="1" class="tbl_exchange" summary="환전 고시 환율 리스트">
#     <caption>
#      환전 고시 환율
#     </caption>
#     <colgroup>
#      <col width="162"/>
#      <col width="92"/>
# ...

# %%
soup.select_one(".sale").text
# Out:
# '1,196.00'

# %%
contents = soup.select("tbody > tr") # 부모 태그 
contents[2].select_one(".sale").text
# Out:
# '1,069.67'

# %%
for content in contents:
    print(content.select_one(".sale").text)
# Out:
# 1,196.00
# 1,382.82
# 1,069.67
# 185.31
# 153.62
# 42.59
# 1,630.09
# 3,106.49
# 953.75
# 1,287.48
# 136.51
# 873.26
# 828.47
# 54.32
# 1.47
# 134.13
# 0.42
# 370.21
# 185.81
# 139.90
# 318.91
# 3,964.99
# 3,172.33
# 325.61
# 1,686.88
# 76.18
# 35.32
# 881.91
# 286.26
# 8.43
# 326.70
# 2.81
# 881.91
# 15.95
# 7.00
# 13.98
# 23.68
# 58.01
# 216.72
# 5.26
# 80.26
# 16.61
# 3.84
# 299.63
